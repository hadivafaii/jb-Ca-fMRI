# %% [markdown]
# # May ??th, 2022 (Misc GABAN, 512 * 3)
#
# **Motivation**: Make group plots (KABA) <br>

# %%
# HIDE CODE


import os
import sys
import nibabel as nib
import networkx as nx
from time import time
from pprint import pprint
from copy import deepcopy as dc
from os.path import join as pjoin
from numpy.ma import masked_where as mwh
from scipy.ndimage import gaussian_filter
from IPython.display import display, IFrame, HTML
from matplotlib.colors import rgb2hex, to_rgb
import matplotlib.pyplot as plt
import seaborn as sns

# set style & no interpolalation
import matplotlib
matplotlib.rcParams['image.interpolation'] = 'none'
sns.set_style('whitegrid')
# %matplotlib inline

# tmp & extras dir
git_dir = pjoin(os.environ['HOME'], 'Dropbox/git')
tmp_dir = pjoin(git_dir, 'jb-Ca-fMRI/tmp')
fig_dir = pjoin(git_dir, 'jb-Ca-fMRI/figs')
extras_dir = pjoin(git_dir, 'jb-Ca-fMRI/_extras')
lfr_dir = pjoin(os.environ['HOME'], 'Documents/workspaces/lfr/binary_overlapping')


# GitHub
sys.path.insert(0, pjoin(git_dir, '_Ca-fMRI'))
from register.atlas import make_tree_graph
from register.parcellation import Parcellation
from analysis.hierarchical import Hierarchical
from analysis.fourier import *
from analysis.bootstrap import *
from analysis.svinet import *
from analysis.group import *
from analysis.lfr import *
from utils.render import *
from utils.plotting import *
from model.mouse import Mice
from model.configuration import Config

# warnings
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
# HIDE CODE


def quick_show(data, vmin=0.1, vmax=None, figsize=None, cmap='magma'):
    num = max(len(tr['proj-top']) for tr in data.values())
    figsize = figsize if figsize else (12.8, 1.25 * len(data))
    fig, axes = create_figure(
        nrows=len(data),
        ncols=num,
        figsize=figsize,
        tight_layout=False,
        constrained_layout=True,
        reshape=True,
    )
 
    for i, (lbl, tr) in enumerate(data.items()):
        for j in range(num):
            ax = axes[i, j]
            if j >= len(tr['proj-top']):
                ax.remove()
            else:
                ax.imshow(mwh(tr['top'] == 0, tr['top']), cmap='Greys_r')
                if np.nanmax(tr['proj-top'][j]) > 1:
                    _cmap = get_cluster_cmap(range(len(tr['proj-top']) - 1))
                    _vmax = None
                else:
                    _cmap = cmap
                    _vmax = vmax
                ax.imshow(
                    mwh(tr['proj-top'][j] < vmin, tr['proj-top'][j]),
                    cmap=_cmap, vmin=vmin, vmax=_vmax,
                )
                if j == 0:
                    ax.set_ylabel(lbl, fontsize=13)
    remove_ticks(axes)
    plt.show()

# %%
mice = Mice(512)
# Out:
# ROI lookup not found, time to run organize_func() . . .
# combine metadata not found, time to run cat_data() . . .

# %%
from register.register import Register
reg = Register(mice)

# %%
reg.set_mode('ca2')

# %%
reg.roi_cutoff, reg.roi_thres
# Out:
# (0, 0.2)

# %%
output = reg.get_accepted_regions()
# Out:
# Name: cortex . . . a total of: 542 regions accepted, 172 regions rejected.
# accept ratio: 75.91 %, reject ratio: 24.09 %, using a presence threshold of 20.0 %

# %%
len(output['cortex']['acc']), len(output['cortex']['rej'])
# Out:
# (542, 172)

# %%
set(output['cortex']['acc']).intersection(output['cortex']['rej'])
# Out:
# set()

# %%
top = ants.image_read(pjoin(mice.cfg.parcel_dir, 'parcel2d-top_10um.nii.gz')).numpy()

regions_top = top[top.nonzero()]
regions_top = np.unique(regions_top)

len(regions_top)
# Out:
# 714

# %%
len(set(regions_top).difference(output['cortex']['acc']))
# Out:
# 172

# %%
len(set(regions_top).difference(output['cortex']['rej']))
# Out:
# 542

# %%
set(regions_top).difference(output['cortex']['acc'] + output['cortex']['rej'])
# Out:
# set()

# %%
top = ants.image_read(pjoin(mice.cfg.parcel_dir, 'parcel2d-top_10um.nii.gz')).numpy()
flat = ants.image_read(pjoin(mice.cfg.parcel_dir, 'parcel2d-flat_10um.nii.gz')).numpy()

# %%
fig, axes = create_figure(1, 2, (12, 4), width_ratios=[1, 1.5])
axes[0].imshow(mwh(top == 0, top), cmap='Spectral')
axes[1].imshow(mwh(flat == 0, flat), cmap='Spectral')

# %%
regions = mice.parcel['cols']
regions = regions[regions.nonzero()]
regions = np.unique(regions)
hcl = mice.parcel.decode(regions)

regions_top = top[top.nonzero()]
regions_top = np.unique(regions_top)

len(regions), len(regions_top)
# Out:
# (1024, 714)

# %%
plt.imshow(mwh(np.isin(flat, regions_top), flat), cmap='Spectral')

# %%
counts_top = collections.Counter(top[top.nonzero()])
counts_top = {r: counts_top.get(r, 0) for r in regions}

# %%
sns.histplot(counts_top.values())
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ## Fig dir

# %%
fig_kws = {
    'transparent': True,
    'bbox_inches': 'tight',
}
fig_dir = pjoin(fig_dir, 'paper')
os.makedirs(fig_dir, exist_ok=True)

# %% [markdown]
# ## Prepare

# %%
mice = Mice(128)

mako = sns.color_palette('mako', as_cmap=True)
rocket = sns.color_palette('rocket', as_cmap=True)
pal = {'ca2': mako(0.6), 'bold-lite': rocket(0.6)}

# %% [markdown]
# ## task = 'rest', k = 8, p = 20

# %%
task = 'rest'

num_k, p = 8, 20
perc = f'p{p}-sample'
props_base = {
    'perc': perc,
    'num_k': num_k,
    'mice': mice,
    'task': task,
    'metric': 'pearson',
    'match_using': 'gam',
    'match_metric': 'euclidean',
    'graph_type': 'real',
    'verbose': False,
}
# props_ca = {'mode': 'ca2', **props_base}
props_bo = {'mode': 'bold', **props_base}

# %%
gr_bo = Group(**props_bo).fit_group()
os.listdir(gr_bo.path)
# Out:
# [
#     'run_pi.npy',
#     'se_indiv-pi_1.0e+02.npy',
#     'se_indiv-pi_1.0e+03.npy',
#     'se_indiv-pi_2.0e+03.npy',
#     'address.npy',
#     'n_runs.npy',
#     'votes.npy',
#     'n_seeds.npy',
#     'run_seed_rank.npy',
#     'run_lam.npy',
#     'se_indiv-pi_5.0e+02.npy'
# ]

# %%
# %%time
pruned = gr_bo.prune(n_resamples=int(2e3), ci=0.99)
# Out:
# CPU times: user 2.28 s, sys: 0 ns, total: 2.28 s
# Wall time: 2.28 s

# %%
pi_sfc = gr_bo.get_surface_pi(pruned['pi_prune_avg'])

tr_sfc = gr_bo.project_vec(pi_sfc, layer=0)
tr_sfc = gr_bo.trim2d(tr_sfc)

tr_0 = gr_bo.project_vec(pruned['pi_prune_avg'], layer=0)
tr_0 = gr_bo.trim2d(tr_0)

tr_1 = gr_bo.project_vec(pruned['pi_prune_avg'], layer=1)
tr_1 = gr_bo.trim2d(tr_1)

tr_2 = gr_bo.project_vec(pruned['pi_prune_avg'], layer=2)
tr_2 = gr_bo.trim2d(tr_2)

# %%
quick_show({'Avg': tr_sfc, 'L0': tr_0, 'L1': tr_1, 'L2': tr_2}, vmin=0.1, vmax=0.6)

# %%
fig, axes = create_figure(2, 4, (12, 4), 'all', 'all')

for i, ax in enumerate(axes.flat):
    ax.imshow(mwh(tr_sfc['flat'] == 0, tr_sfc['flat']), cmap='Greys_r')
    ax.imshow(mwh(tr_sfc['proj-flat'][i] < 0.05, tr_sfc['proj-flat'][i]), cmap='magma')

# %%
collections.Counter(np.round(pi_sfc.sum(0), 7))
# Out:
# Counter({0.0: 817, 1.0: 255})

# %%
collections.Counter(np.round(pruned['pi_prune_avg'].sum(0), 7))
# Out:
# Counter({1.0: 1072})

# %%
pruned['pi_prune_run'].shape
# Out:
# (10, 3, 4, 8, 1072)

# %%
h = sp_stats.entropy(pruned['pi_prune_run'], axis=-2) / np.log(8)
sns.histplot(h[np.isfinite(h)]);
h.shape
# Out:
# (10, 3, 4, 1072)

# %%
h = bn.nanmean(bn.nanmean(bn.nanmean(h, 2), 1), 0)
sns.histplot(h[np.isfinite(h)]);
h.shape
# Out:
# (1072,)

# %%
h_sfc = gr_bo.get_surface_pi(h.reshape(1, -1)).squeeze()

# %%
sns.histplot(h_sfc[h_sfc.nonzero()])
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
tr_h = gr_bo.project_vec(h_sfc)
tr_h = gr_bo.trim2d(tr_h)

# %%
thres = 0.1
vmin = 0.2

fig, axes = create_figure(1, 2, (10, 3.5), width_ratios=[1, 2])
axes[0].imshow(
    mwh(tr_h['proj-top'][0] < thres, tr_h['proj-top'][0]),
    cmap='coolwarm',
    vmin=vmin,
    vmax=np.nanmax(h_sfc),
)
axes[1].imshow(
    mwh(tr_h['proj-flat'][0] < thres, tr_h['proj-flat'][0]),
    cmap='coolwarm',
    vmin=vmin,
    vmax=np.nanmax(h_sfc),
)
remove_ticks(axes)

# %%
d2p = {}

# bold (+1)
props_bo['num_k'] += 1
gr_bo = Group(**props_bo).fit_group()
gr_bo.pi = bn.nanmean(bn.nanmean(bn.nanmean(bn.nanmean(
    gr_bo.run_pi, 3), 2), 1), 0)
d2p['bold+1'] = gr_bo.trim2d(gr_bo.project_vec())

# bold (merged x 2)
gr_bo = Group(**props_bo).fit_group()
_ = gr_bo._merge_bold(0.25)
_ = gr_bo._merge_bold(0.5)
d2p['bold-1'] = gr_bo.trim2d(gr_bo.project_vec())

# bold (merged)
gr_bo = Group(**props_bo).fit_group()
_ = gr_bo._merge_bold(0.25)
d2p['bold'] = gr_bo.trim2d(gr_bo.project_vec())

# ca2
pi_ca = {}
for b in [(0.01, 0.50), 0.5]:
    mice.setup_func_data(task, band_ca=b)
    gr_ca = Group(**props_ca).fit_group()
    gr_ca.pi = bn.nanmean(bn.nanmean(bn.nanmean(bn.nanmean(
        gr_ca.run_pi, 3), 2), 1), 0)
    d2p[f'ca2\nb={b}'.replace(' ', '')] = gr_ca.trim2d(gr_ca.project_vec())
    pi_ca[b] = gr_ca.pi

# %%
mappings = find_best_mappings(gr_bo.pi, pi_ca)
for b, gmap in mappings.items():
    new_ids = list(gmap.values())
    # if b == 0.5:
    #     i, j = new_ids[3], new_ids[4]
    #     new_ids[3], new_ids[4] = j, i
    pi = pi_ca[b][new_ids]
    d2p[f'ca2\nb={b}'.replace(' ', '')] = gr_ca.trim2d(gr_ca.project_vec(pi))

# %%
quick_show(d2p, vmin=0.10, vmax=0.8)

# %% [markdown]
# ## task = 'all', k = 8, p = 20

# %%
## task = 'all', k = 8, p = 20

task = 'all'

num_k, p = 8, 20
perc = f'p{p}-sample'
props_base = {
    'perc': perc,
    'num_k': num_k,
    'mice': mice,
    'task': task,
    'metric': 'pearson',
    'match_using': 'gam',
    'match_metric': 'euclidean',
    'graph_type': 'real',
    'verbose': False,
}
props_ca = {'mode': 'ca2', **props_base}
props_bo = {'mode': 'bold-lite', **props_base}

d2p = {}

# bold (+1)
props_bo['num_k'] += 1
gr_bo = Group(**props_bo).fit_group()
gr_bo.pi = bn.nanmean(bn.nanmean(bn.nanmean(bn.nanmean(
    gr_bo.run_pi, 3), 2), 1), 0)
d2p['bold+1'] = gr_bo.trim2d(gr_bo.project_vec())

# bold (merged x 2)
# gr_bo = Group(**props_bo).fit_group()
# _ = gr_bo._merge_bold(0.25)
# _ = gr_bo._merge_bold(0.5)
# d2p['bold-1'] = gr_bo.trim2d(gr_bo.project_vec())

# bold (merged)
gr_bo = Group(**props_bo).fit_group()
_ = gr_bo._merge_bold(0.25)
d2p['bold'] = gr_bo.trim2d(gr_bo.project_vec())

# ca2
pi_ca = {}
for b in [(0.01, 0.50), 0.5]:
    mice.setup_func_data(task, band_ca=b)
    gr_ca = Group(**props_ca).fit_group()
    gr_ca.pi = bn.nanmean(bn.nanmean(bn.nanmean(bn.nanmean(
        gr_ca.run_pi, 3), 2), 1), 0)
    d2p[f'ca2\nb={b}'.replace(' ', '')] = gr_ca.trim2d(gr_ca.project_vec())
    pi_ca[b] = gr_ca.pi

mappings = find_best_mappings(gr_bo.pi, pi_ca)
for b, gmap in mappings.items():
    new_ids = list(gmap.values())
    # if b == 0.5:
    #     i, j = new_ids[3], new_ids[4]
    #     new_ids[3], new_ids[4] = j, i
    pi = pi_ca[b][new_ids]
    d2p[f'ca2\nb={b}'.replace(' ', '')] = gr_ca.trim2d(gr_ca.project_vec(pi))

quick_show(d2p, vmin=0.10, vmax=0.8)

task = 'all'

num_k, p = 8, 20
perc = f'p{p}-sample'
props_base = {
    'perc': perc,
    'num_k': num_k,
    'mice': mice,
    'task': task,
    'metric': 'pearson',
    'match_using': 'gam',
    'match_metric': 'euclidean',
    'graph_type': 'real',
    'verbose': False,
}
props_ca = {'mode': 'ca2', **props_base}
props_bo = {'mode': 'bold-lite', **props_base}

# %%
d2p = {}

# bold (+1)
props_bo['num_k'] += 1
gr_bo = Group(**props_bo).fit_group()
gr_bo.pi = bn.nanmean(bn.nanmean(bn.nanmean(bn.nanmean(
    gr_bo.run_pi, 3), 2), 1), 0)
d2p['bold+1'] = gr_bo.trim2d(gr_bo.project_vec())

# bold (merged x 2)
# gr_bo = Group(**props_bo).fit_group()
# _ = gr_bo._merge_bold(0.25)
# _ = gr_bo._merge_bold(0.5)
# d2p['bold-1'] = gr_bo.trim2d(gr_bo.project_vec())

# bold (merged)
gr_bo = Group(**props_bo).fit_group()
_ = gr_bo._merge_bold(0.25)
d2p['bold'] = gr_bo.trim2d(gr_bo.project_vec())

# ca2
pi_ca = {}
for b in [(0.01, 0.50), 0.5]:
    mice.setup_func_data(task, band_ca=b)
    gr_ca = Group(**props_ca).fit_group()
    gr_ca.pi = bn.nanmean(bn.nanmean(bn.nanmean(bn.nanmean(
        gr_ca.run_pi, 3), 2), 1), 0)
    d2p[f'ca2\nb={b}'.replace(' ', '')] = gr_ca.trim2d(gr_ca.project_vec())
    pi_ca[b] = gr_ca.pi

# %%
mappings = find_best_mappings(gr_bo.pi, pi_ca)
for b, gmap in mappings.items():
    new_ids = list(gmap.values())
    # if b == 0.5:
    #     i, j = new_ids[3], new_ids[4]
    #     new_ids[3], new_ids[4] = j, i
    pi = pi_ca[b][new_ids]
    d2p[f'ca2\nb={b}'.replace(' ', '')] = gr_ca.trim2d(gr_ca.project_vec(pi))

# %%
quick_show(d2p, vmin=0.10, vmax=0.8)

# %% [markdown]
# ## task = 'all', k = 8, p = 10

# %%
task = 'all'

num_k, p = 8, 10
perc = f'p{p}-sample'
props_base = {
    'perc': perc,
    'num_k': num_k,
    'mice': mice,
    'task': task,
    'metric': 'pearson',
    'match_using': 'gam',
    'match_metric': 'euclidean',
    'graph_type': 'real',
    'verbose': False,
}
props_ca = {'mode': 'ca2', **props_base}
props_bo = {'mode': 'bold-lite', **props_base}

# %%
d2p = {}

# bold (+1)
props_bo['num_k'] += 1
gr_bo = Group(**props_bo).fit_group()
gr_bo.pi = bn.nanmean(bn.nanmean(bn.nanmean(bn.nanmean(
    gr_bo.run_pi, 3), 2), 1), 0)
d2p['bold+1'] = gr_bo.trim2d(gr_bo.project_vec())

# bold (merged x 2)
# gr_bo = Group(**props_bo).fit_group()
# _ = gr_bo._merge_bold(0.25)
# _ = gr_bo._merge_bold(0.5)
# d2p['bold-1'] = gr_bo.trim2d(gr_bo.project_vec())

# bold (merged)
gr_bo = Group(**props_bo).fit_group()
_ = gr_bo._merge_bold(0.25)
d2p['bold'] = gr_bo.trim2d(gr_bo.project_vec())

# ca2
pi_ca = {}
for b in [(0.01, 0.50), 0.5]:
    mice.setup_func_data(task, band_ca=b)
    gr_ca = Group(**props_ca).fit_group()
    gr_ca.pi = bn.nanmean(bn.nanmean(bn.nanmean(bn.nanmean(
        gr_ca.run_pi, 3), 2), 1), 0)
    d2p[f'ca2\nb={b}'.replace(' ', '')] = gr_ca.trim2d(gr_ca.project_vec())
    pi_ca[b] = gr_ca.pi

# %%
mappings = find_best_mappings(gr_bo.pi, pi_ca)
for b, gmap in mappings.items():
    new_ids = list(gmap.values())
    # if b == 0.5:
    #     i, j = new_ids[3], new_ids[4]
    #     new_ids[3], new_ids[4] = j, i
    pi = pi_ca[b][new_ids]
    d2p[f'ca2\nb={b}'.replace(' ', '')] = gr_ca.trim2d(gr_ca.project_vec(pi))

# %%
quick_show(d2p, vmin=0.10, vmax=0.8)

# %% [markdown]
# ## task = 'all', k = 7, p = 10

# %%
task = 'all'

num_k, p = 7, 10
perc = f'p{p}-sample'
props_base = {
    'perc': perc,
    'num_k': num_k,
    'mice': mice,
    'task': task,
    'metric': 'pearson',
    'match_using': 'gam',
    'match_metric': 'euclidean',
    'graph_type': 'real',
    'verbose': False,
}
props_ca = {'mode': 'ca2', **props_base}
props_bo = {'mode': 'bold-lite', **props_base}

# %%
d2p = {}

# bold (+1)
props_bo['num_k'] += 1
gr_bo = Group(**props_bo).fit_group()
gr_bo.pi = bn.nanmean(bn.nanmean(bn.nanmean(bn.nanmean(
    gr_bo.run_pi, 3), 2), 1), 0)
d2p['bold+1'] = gr_bo.trim2d(gr_bo.project_vec())

# bold (merged x 2)
# gr_bo = Group(**props_bo).fit_group()
# _ = gr_bo._merge_bold(0.25)
# _ = gr_bo._merge_bold(0.5)
# d2p['bold-1'] = gr_bo.trim2d(gr_bo.project_vec())

# bold (merged)
gr_bo = Group(**props_bo).fit_group()
_ = gr_bo._merge_bold(0.25)
d2p['bold'] = gr_bo.trim2d(gr_bo.project_vec())

# ca2
pi_ca = {}
for b in [(0.01, 0.50), 0.5]:
    mice.setup_func_data(task, band_ca=b)
    gr_ca = Group(**props_ca).fit_group()
    gr_ca.pi = bn.nanmean(bn.nanmean(bn.nanmean(bn.nanmean(
        gr_ca.run_pi, 3), 2), 1), 0)
    d2p[f'ca2\nb={b}'.replace(' ', '')] = gr_ca.trim2d(gr_ca.project_vec())
    pi_ca[b] = gr_ca.pi

# %%
mappings = find_best_mappings(gr_bo.pi, pi_ca)
for b, gmap in mappings.items():
    new_ids = list(gmap.values())
    # if b == 0.5:
    #     i, j = new_ids[3], new_ids[4]
    #     new_ids[3], new_ids[4] = j, i
    pi = pi_ca[b][new_ids]
    d2p[f'ca2\nb={b}'.replace(' ', '')] = gr_ca.trim2d(gr_ca.project_vec(pi))

# %%
quick_show(d2p, vmin=0.10, vmax=0.8)

# %% [markdown]
# ## task = 'rest'

# %%
task = 'rest'

num_k, p = 8, 10
perc = f'p{p}-sample'
props_base = {
    'perc': perc,
    'num_k': num_k,
    'mice': mice,
    'task': task,
    'metric': 'pearson',
    'match_using': 'gam',
    'match_metric': 'euclidean',
    'graph_type': 'real',
    'verbose': False,
}
props_ca = {'mode': 'ca2', **props_base}
props_bo = {'mode': 'bold-lite', **props_base}

# %%
d2p = {}

# bold (+1)
props_bo['num_k'] += 1
gr_bo = Group(**props_bo).fit_group()
gr_bo.pi = bn.nanmean(bn.nanmean(bn.nanmean(bn.nanmean(
    gr_bo.run_pi, 3), 2), 1), 0)
d2p['bold+1'] = gr_bo.trim2d(gr_bo.project_vec())

# bold (merged)
gr_bo = Group(**props_bo).fit_group()
_ = gr_bo._merge_bold(0.25)
d2p['bold'] = gr_bo.trim2d(gr_bo.project_vec())

# ca2
pi_ca = {}
for b in [(0.01, 0.50), 0.5]:
    mice.setup_func_data(task, band_ca=b)
    gr_ca = Group(**props_ca).fit_group()
    gr_ca.pi = bn.nanmean(bn.nanmean(bn.nanmean(bn.nanmean(
        gr_ca.run_pi, 3), 2), 1), 0)
    d2p[f'ca2\nb={b}'.replace(' ', '')] = gr_ca.trim2d(gr_ca.project_vec())
    pi_ca[b] = gr_ca.pi

# %%
mappings = find_best_mappings(gr_bo.pi, pi_ca)
for b, gmap in mappings.items():
    new_ids = list(gmap.values())
    # if b == 0.5:
    #     i, j = new_ids[3], new_ids[4]
    #     new_ids[3], new_ids[4] = j, i
    pi = pi_ca[b][new_ids]
    d2p[f'ca2\nb={b}'.replace(' ', '')] = gr_ca.trim2d(gr_ca.project_vec(pi))

# %%
quick_show(d2p, vmin=0.10, vmax=0.8)

# %% [markdown]
# ## task = 'led'

# %%
task = 'led'

num_k, p = 8, 10
perc = f'p{p}-sample'
props_base = {
    'perc': perc,
    'num_k': num_k,
    'mice': mice,
    'task': task,
    'metric': 'pearson',
    'match_using': 'gam',
    'match_metric': 'euclidean',
    'graph_type': 'real',
    'verbose': False,
}
props_ca = {'mode': 'ca2', **props_base}
props_bo = {'mode': 'bold-lite', **props_base}

# %%
d2p = {}

# bold (+1)
props_bo['num_k'] += 1
gr_bo = Group(**props_bo).fit_group()
gr_bo.pi = bn.nanmean(bn.nanmean(bn.nanmean(bn.nanmean(
    gr_bo.run_pi, 3), 2), 1), 0)
d2p['bold+1'] = gr_bo.trim2d(gr_bo.project_vec())

# bold (merged)
gr_bo = Group(**props_bo).fit_group()
_ = gr_bo._merge_bold(0.25)
d2p['bold'] = gr_bo.trim2d(gr_bo.project_vec())

# ca2
pi_ca = {}
for b in [(0.01, 0.50), 0.5, 0.01]:
    mice.setup_func_data(task, band_ca=b)
    gr_ca = Group(**props_ca).fit_group()
    gr_ca.pi = bn.nanmean(bn.nanmean(bn.nanmean(bn.nanmean(
        gr_ca.run_pi, 3), 2), 1), 0)
    d2p[f'ca2\nb={b}'.replace(' ', '')] = gr_ca.trim2d(gr_ca.project_vec())
    pi_ca[b] = gr_ca.pi

# %%
mappings = find_best_mappings(gr_bo.pi, pi_ca)
for b, gmap in mappings.items():
    new_ids = list(gmap.values())
    # if b == 0.5:
    #     i, j = new_ids[3], new_ids[4]
    #     new_ids[3], new_ids[4] = j, i
    pi = pi_ca[b][new_ids]
    d2p[f'ca2\nb={b}'.replace(' ', '')] = gr_ca.trim2d(gr_ca.project_vec(pi))

# %%
quick_show(d2p, vmin=0.10, vmax=0.8)
