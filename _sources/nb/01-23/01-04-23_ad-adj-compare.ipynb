# %% [markdown]
# # (04) AD: adj compare
#
# **Motivation**: Compare saved adjacency matrices, visuzlie them. Possibly KMeans. <br>

# %%
# HIDE CODE


import os
import sys
from pprint import pprint
from copy import deepcopy as dc
from os.path import join as pjoin
from scipy.ndimage import gaussian_filter
from IPython.display import display, IFrame, HTML

# tmp & extras dir
git_dir = pjoin(os.environ['HOME'], 'Dropbox/git')
extras_dir = pjoin(git_dir, 'jb-Ca-fMRI/_extras')
fig_base_dir = pjoin(git_dir, 'jb-Ca-fMRI/figs')
tmp_dir = pjoin(git_dir, 'jb-Ca-fMRI/tmp')

# GitHub
sys.path.insert(0, pjoin(git_dir, '_Ca-fMRI'))
from figures.fighelper import *
from analysis.final import *
from utils.render import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
from tqdm.notebook import tqdm
# %matplotlib inline
set_style()

# %% [markdown]
# ## Prepare

# %%
mice = Mice(Config(128, resolution=25))
mice.set_band(band_bo=(0.008,0.28))
# Out:
# ROI lookup not found, time to run organize_func() . . .
# combine metadata not found, time to run cat_data() . . .

# %% [markdown]
# ## Load

# %% [markdown]
# ### Adj

# %%
adj = np.load(pjoin(tmp_dir, 'AD_adj.npy'), allow_pickle=True).item()
len(adj), 348 + 118 + 69 + 2 + 10
# Out:
# (547, 547)

# %% [markdown]
# ### Node2id

# %%
n2i = np.load(pjoin(tmp_dir, 'AD_n2i.npy'), allow_pickle=True).item()
i2n = {i: n for n, i in n2i.items()}

n2l = {}
for n, i in n2i.items():
    info = mice.parcel.get(i)
    if info['acro'] == 'Isocortex':
        n2l[n] = f"{info['hemis']}-{info['region']}-{info['layer']}"
    else:
        n2l[n] = f"{info['hemis']}-{info['region']}"
mice.node_lookup['bold'] = n2l
mice.node_lookup['ca2'] = {
    n: lbl for n, lbl in n2l.items()
    if len(lbl.split('-')) == 3
}
bs = Base(mice, mode='ca2')

# %% [markdown]
# ## Correlations

# %%
for g in ['WT', 'DKI']:
    for ses in [1, 2, 3]:
        key = f"sub-{g}_ses-{ses}"
        a = adj[key]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
#       2 for ses in [1, 2, 3]:
#       3     key = f"sub-{g}_ses-{ses}"
# ----> 4     a = adj[key]
#
# KeyError: 'sub-WT_ses-1'

# %%
list(adj)
# Out:
# [
#     'sub-DKI01_ses-1_run-1',
#     'sub-DKI01_ses-1_run-2',
#     'sub-DKI01_ses-1_run-3',
#     'sub-DKI02_ses-1_run-1',
#     'sub-DKI02_ses-1_run-2',
#     'sub-DKI02_ses-1_run-3',
#     'sub-DKI02_ses-2_run-1',
#     'sub-DKI02_ses-2_run-2',
#     'sub-DKI02_ses-2_run-3',
#     'sub-DKI03_ses-1_run-1',
#     'sub-DKI03_ses-1_run-2',
#     'sub-DKI03_ses-1_run-3',
#     'sub-DKI04_ses-1_run-1',
#     'sub-DKI04_ses-1_run-2',
#     'sub-DKI04_ses-1_run-3',
#     'sub-DKI04_ses-2_run-1',
#     'sub-DKI04_ses-2_run-2',
#     'sub-DKI04_ses-2_run-3',
#     'sub-DKI05_ses-1_run-1',
#     'sub-DKI05_ses-1_run-2',
#     'sub-DKI05_ses-1_run-3',
#     'sub-DKI06_ses-1_run-1',
#     'sub-DKI06_ses-1_run-2',
#     'sub-DKI06_ses-1_run-3',
#     'sub-DKI06_ses-2_run-1',
#     'sub-DKI06_ses-2_run-2',
#     'sub-DKI06_ses-2_run-3',
#     'sub-DKI07_ses-1_run-1',
#     'sub-DKI07_ses-1_run-2',
#     'sub-DKI07_ses-1_run-3',
#     'sub-DKI07_ses-2_run-1',
#     'sub-DKI07_ses-2_run-2',
#     'sub-DKI07_ses-2_run-3',
#     'sub-DKI08_ses-1_run-1',
#     'sub-DKI08_ses-1_run-2',
#     'sub-DKI08_ses-1_run-3',
#     'sub-DKI09_ses-1_run-1',
#     'sub-DKI09_ses-1_run-2',
#     'sub-DKI09_ses-1_run-3',
#     'sub-DKI09_ses-2_run-1',
#     'sub-DKI09_ses-2_run-2',
#     'sub-DKI09_ses-2_run-3',
#     'sub-DKI09_ses-3_run-1',
#     'sub-DKI09_ses-3_run-2',
#     'sub-DKI09_ses-3_run-3',
#     'sub-DKI10_ses-1_run-1',
#     'sub-DKI10_ses-1_run-2',
#     'sub-DKI10_ses-1_run-3',
#     'sub-DKI10_ses-2_run-1',
#     'sub-DKI10_ses-2_run-2',
#     'sub-DKI10_ses-2_run-3',
#     'sub-DKI10_ses-3_run-1',
#     'sub-DKI10_ses-3_run-2',
#     'sub-DKI10_ses-3_run-3',
#     'sub-DKI11_ses-1_run-1',
#     'sub-DKI11_ses-1_run-2',
#     'sub-DKI11_ses-1_run-3',
#     'sub-DKI11_ses-2_run-1',
#     'sub-DKI11_ses-2_run-2',
#     'sub-DKI11_ses-2_run-3',
#     'sub-DKI11_ses-3_run-1',
#     'sub-DKI11_ses-3_run-2',
#     'sub-DKI11_ses-3_run-3',
#     'sub-DKI12_ses-1_run-1',
#     'sub-DKI12_ses-1_run-2',
#     'sub-DKI12_ses-1_run-3',
#     'sub-DKI12_ses-2_run-1',
#     'sub-DKI12_ses-2_run-2',
#     'sub-DKI12_ses-2_run-3',
#     'sub-DKI12_ses-3_run-1',
#     'sub-DKI12_ses-3_run-2',
#     'sub-DKI12_ses-3_run-3',
#     'sub-DKI13_ses-1_run-1',
#     'sub-DKI13_ses-1_run-2',
#     'sub-DKI13_ses-1_run-3',
#     'sub-DKI14_ses-1_run-1',
#     'sub-DKI14_ses-1_run-2',
#     'sub-DKI14_ses-1_run-3',
#     'sub-DKI14_ses-3_run-1',
#     'sub-DKI14_ses-3_run-2',
#     'sub-DKI14_ses-3_run-3',
#     'sub-DKI15_ses-1_run-1',
#     'sub-DKI15_ses-1_run-2',
#     'sub-DKI15_ses-1_run-3',
#     'sub-DKI15_ses-3_run-1',
#     'sub-DKI15_ses-3_run-2',
#     'sub-DKI15_ses-3_run-3',
#     'sub-DKI16_ses-3_run-1',
#     'sub-DKI16_ses-3_run-2',
#     'sub-DKI17_ses-3_run-1',
#     'sub-DKI17_ses-3_run-2',
#     'sub-DKI17_ses-3_run-3',
#     'sub-DKI18_ses-3_run-1',
#     'sub-DKI18_ses-3_run-2',
#     'sub-DKI18_ses-3_run-3',
#     'sub-DKI19_ses-3_run-1',
#     'sub-DKI19_ses-3_run-2',
#     'sub-DKI19_ses-3_run-3',
#     'sub-DKI20_ses-3_run-1',
#     'sub-DKI20_ses-3_run-2',
#     'sub-DKI20_ses-3_run-3',
#     'sub-DKI21_ses-2_run-1',
#     'sub-DKI21_ses-2_run-2',
#     'sub-DKI21_ses-2_run-3',
#     'sub-DKI22_ses-5_run-1',
#     'sub-DKI22_ses-5_run-2',
#     'sub-DKI22_ses-5_run-3',
#     'sub-DKI22_ses-6_run-1',
#     'sub-DKI22_ses-6_run-2',
#     'sub-DKI22_ses-6_run-3',
#     'sub-DKI23_ses-5_run-1',
#     'sub-DKI23_ses-5_run-2',
#     'sub-DKI23_ses-5_run-3',
#     'sub-DKI23_ses-6_run-1',
#     'sub-DKI23_ses-6_run-2',
#     'sub-DKI23_ses-6_run-3',
#     'sub-DKI24_ses-5_run-1',
#     'sub-DKI24_ses-5_run-2',
#     'sub-DKI24_ses-5_run-3',
#     'sub-DKI24_ses-6_run-1',
#     'sub-DKI24_ses-6_run-2',
#     'sub-DKI24_ses-6_run-3',
#     'sub-DKI25_ses-5_run-1',
#     'sub-DKI25_ses-5_run-2',
#     'sub-DKI25_ses-5_run-3',
#     'sub-DKI25_ses-6_run-1',
#     'sub-DKI25_ses-6_run-2',
#     'sub-DKI25_ses-6_run-3',
#     'sub-DKI26_ses-5_run-1',
#     'sub-DKI26_ses-5_run-2',
#     'sub-DKI26_ses-6_run-1',
#     'sub-DKI26_ses-6_run-2',
#     'sub-DKI26_ses-6_run-3',
#     'sub-DKI27_ses-5_run-1',
#     'sub-DKI27_ses-5_run-2',
#     'sub-DKI27_ses-5_run-3',
#     'sub-DKI27_ses-6_run-1',
#     'sub-DKI27_ses-6_run-2',
#     'sub-DKI27_ses-6_run-3',
#     'sub-DKI28_ses-5_run-1',
#     'sub-DKI28_ses-5_run-2',
#     'sub-DKI28_ses-5_run-3',
#     'sub-DKI28_ses-6_run-1',
#     'sub-DKI28_ses-6_run-2',
#     'sub-DKI28_ses-6_run-3',
#     'sub-DKI29_ses-5_run-1',
#     'sub-DKI29_ses-5_run-2',
#     'sub-DKI29_ses-5_run-3',
#     'sub-DKI29_ses-6_run-1',
#     'sub-DKI29_ses-6_run-2',
#     'sub-DKI30_ses-5_run-1',
#     'sub-DKI30_ses-5_run-2',
#     'sub-DKI30_ses-5_run-3',
#     'sub-DKI30_ses-6_run-1',
#     'sub-DKI30_ses-6_run-2',
#     'sub-DKI30_ses-6_run-3',
#     'sub-DKI31_ses-5_run-1',
#     'sub-DKI31_ses-5_run-2',
#     'sub-DKI31_ses-5_run-3',
#     'sub-DKI31_ses-6_run-1',
#     'sub-DKI31_ses-6_run-2',
#     'sub-DKI31_ses-6_run-3',
#     'sub-DKI32_ses-5_run-1',
#     'sub-DKI32_ses-5_run-2',
#     'sub-DKI32_ses-5_run-3',
#     'sub-DKI32_ses-6_run-1',
#     'sub-DKI32_ses-6_run-2',
#     'sub-DKI32_ses-6_run-3',
#     'sub-DKI33_ses-5_run-1',
#     'sub-DKI33_ses-5_run-2',
#     'sub-DKI33_ses-5_run-3',
#     'sub-DKI33_ses-6_run-1',
#     'sub-DKI33_ses-6_run-2',
#     'sub-DKI33_ses-6_run-3',
#     'sub-DKI34_ses-5_run-1',
#     'sub-DKI34_ses-5_run-2',
#     'sub-DKI34_ses-5_run-3',
#     'sub-DKI34_ses-6_run-1',
#     'sub-DKI34_ses-6_run-2',
#     'sub-DKI34_ses-6_run-3',
#     'sub-DKI35_ses-5_run-1',
#     'sub-DKI35_ses-5_run-2',
#     'sub-DKI35_ses-5_run-3',
#     'sub-DKI36_ses-5_run-1',
#     'sub-DKI36_ses-5_run-2',
#     'sub-DKI36_ses-5_run-3',
#     'sub-DKI36_ses-6_run-1',
#     'sub-DKI36_ses-6_run-2',
#     'sub-DKI36_ses-6_run-3',
#     'sub-DKI37_ses-5_run-1',
#     'sub-DKI37_ses-5_run-2',
#     'sub-DKI37_ses-6_run-1',
#     'sub-DKI37_ses-6_run-2',
#     'sub-DKI38_ses-5_run-1',
#     'sub-DKI38_ses-5_run-2',
#     'sub-DKI38_ses-5_run-3',
#     'sub-DKI39_ses-5_run-1',
#     'sub-DKI39_ses-5_run-2',
#     'sub-DKI39_ses-5_run-3',
#     'sub-DKI39_ses-6_run-1',
#     'sub-DKI39_ses-6_run-2',
#     'sub-DKI39_ses-6_run-3',
#     'sub-DKI40_ses-5_run-1',
#     'sub-DKI40_ses-5_run-2',
#     'sub-DKI40_ses-5_run-3',
#     'sub-DKI40_ses-6_run-1',
#     'sub-DKI40_ses-6_run-2',
#     'sub-DKI40_ses-6_run-3',
#     'sub-DKI41_ses-5_run-1',
#     'sub-DKI41_ses-5_run-2',
#     'sub-DKI41_ses-5_run-3',
#     'sub-DKI41_ses-6_run-1',
#     'sub-DKI41_ses-6_run-2',
#     'sub-DKI41_ses-6_run-3',
#     'sub-DKI42_ses-2_run-1',
#     'sub-DKI42_ses-2_run-2',
#     'sub-DKI42_ses-2_run-3',
#     'sub-DKI43_ses-2_run-1',
#     'sub-DKI43_ses-2_run-2',
#     'sub-DKI43_ses-2_run-3',
#     'sub-DKI44_ses-2_run-1',
#     'sub-DKI44_ses-2_run-2',
#     'sub-DKI44_ses-2_run-3',
#     'sub-WT01_ses-1_run-1',
#     'sub-WT01_ses-1_run-2',
#     'sub-WT01_ses-1_run-3',
#     'sub-WT01_ses-2_run-1',
#     'sub-WT01_ses-2_run-2',
#     'sub-WT01_ses-2_run-3',
#     'sub-WT01_ses-3_run-1',
#     'sub-WT01_ses-3_run-2',
#     'sub-WT01_ses-3_run-3',
#     'sub-WT02_ses-1_run-1',
#     'sub-WT02_ses-1_run-2',
#     'sub-WT02_ses-1_run-3',
#     'sub-WT02_ses-2_run-1',
#     'sub-WT02_ses-2_run-2',
#     'sub-WT02_ses-2_run-3',
#     'sub-WT02_ses-3_run-1',
#     'sub-WT02_ses-3_run-2',
#     'sub-WT02_ses-3_run-3',
#     'sub-WT03_ses-1_run-1',
#     'sub-WT03_ses-1_run-2',
#     'sub-WT03_ses-1_run-3',
#     'sub-WT03_ses-2_run-1',
#     'sub-WT03_ses-2_run-2',
#     'sub-WT03_ses-2_run-3',
#     'sub-WT04_ses-1_run-1',
#     'sub-WT04_ses-1_run-2',
#     'sub-WT04_ses-1_run-3',
#     'sub-WT04_ses-2_run-1',
#     'sub-WT04_ses-2_run-2',
#     'sub-WT04_ses-2_run-3',
#     'sub-WT05_ses-1_run-1',
#     'sub-WT05_ses-1_run-2',
#     'sub-WT05_ses-1_run-3',
#     'sub-WT05_ses-2_run-1',
#     'sub-WT05_ses-2_run-2',
#     'sub-WT05_ses-2_run-3',
#     'sub-WT06_ses-1_run-1',
#     'sub-WT06_ses-1_run-2',
#     'sub-WT06_ses-1_run-3',
#     'sub-WT06_ses-2_run-1',
#     'sub-WT06_ses-2_run-2',
#     'sub-WT06_ses-2_run-3',
#     'sub-WT07_ses-1_run-1',
#     'sub-WT07_ses-1_run-2',
#     'sub-WT07_ses-1_run-3',
#     'sub-WT07_ses-1_run-4',
#     'sub-WT07_ses-2_run-1',
#     'sub-WT07_ses-2_run-2',
#     'sub-WT07_ses-2_run-3',
#     'sub-WT08_ses-1_run-1',
#     'sub-WT08_ses-1_run-2',
#     'sub-WT08_ses-2_run-1',
#     'sub-WT08_ses-2_run-2',
#     'sub-WT08_ses-2_run-3',
#     'sub-WT09_ses-1_run-1',
#     'sub-WT09_ses-1_run-2',
#     'sub-WT09_ses-1_run-3',
#     'sub-WT09_ses-2_run-1',
#     'sub-WT09_ses-2_run-2',
#     'sub-WT09_ses-2_run-3',
#     'sub-WT10_ses-1_run-1',
#     'sub-WT10_ses-1_run-2',
#     'sub-WT10_ses-1_run-3',
#     'sub-WT10_ses-2_run-1',
#     'sub-WT10_ses-2_run-2',
#     'sub-WT10_ses-2_run-3',
#     'sub-WT11_ses-3_run-1',
#     'sub-WT11_ses-3_run-2',
#     'sub-WT11_ses-3_run-3',
#     'sub-WT12_ses-3_run-1',
#     'sub-WT12_ses-3_run-2',
#     'sub-WT12_ses-3_run-3',
#     'sub-WT13_ses-3_run-1',
#     'sub-WT13_ses-3_run-2',
#     'sub-WT13_ses-3_run-3',
#     'sub-WT14_ses-3_run-1',
#     'sub-WT14_ses-3_run-2',
#     'sub-WT14_ses-3_run-3',
#     'sub-WT15_ses-3_run-1',
#     'sub-WT15_ses-3_run-2',
#     'sub-WT16_ses-3_run-1',
#     'sub-WT16_ses-3_run-2',
#     'sub-WT16_ses-3_run-3',
#     'sub-WT17_ses-3_run-1',
#     'sub-WT17_ses-3_run-2',
#     'sub-WT17_ses-3_run-3',
#     'sub-WT18_ses-5_run-1',
#     'sub-WT18_ses-5_run-2',
#     'sub-WT18_ses-5_run-3',
#     'sub-WT18_ses-6_run-1',
#     'sub-WT18_ses-6_run-2',
#     'sub-WT18_ses-6_run-3',
#     'sub-WT19_ses-5_run-1',
#     'sub-WT19_ses-5_run-2',
#     'sub-WT19_ses-5_run-3',
#     'sub-WT19_ses-6_run-1',
#     'sub-WT19_ses-6_run-2',
#     'sub-WT19_ses-6_run-3',
#     'sub-WT20_ses-5_run-1',
#     'sub-WT20_ses-5_run-2',
#     'sub-WT20_ses-5_run-3',
#     'sub-WT20_ses-6_run-1',
#     'sub-WT20_ses-6_run-2',
#     'sub-WT20_ses-6_run-3',
#     'sub-WT21_ses-5_run-1',
#     'sub-WT21_ses-5_run-2',
#     'sub-WT21_ses-5_run-3',
#     'sub-WT21_ses-6_run-1',
#     'sub-WT21_ses-6_run-2',
#     'sub-WT21_ses-6_run-3',
#     'sub-WT22_ses-5_run-1',
#     'sub-WT22_ses-5_run-2',
#     'sub-WT22_ses-5_run-3',
#     'sub-WT22_ses-6_run-1',
#     'sub-WT22_ses-6_run-2',
#     'sub-WT22_ses-6_run-3',
#     'sub-WT23_ses-5_run-1',
#     'sub-WT23_ses-5_run-2',
#     'sub-WT23_ses-5_run-3',
#     'sub-WT24_ses-5_run-1',
#     'sub-WT24_ses-5_run-2',
#     'sub-WT24_ses-5_run-3',
#     'sub-WT25_ses-5_run-1',
#     'sub-WT25_ses-5_run-2',
#     'sub-WT25_ses-5_run-3',
#     'sub-DKI01_ses-1',
#     'sub-DKI02_ses-1',
#     'sub-DKI02_ses-2',
#     'sub-DKI03_ses-1',
#     'sub-DKI04_ses-1',
#     'sub-DKI04_ses-2',
#     'sub-DKI05_ses-1',
#     'sub-DKI06_ses-1',
#     'sub-DKI06_ses-2',
#     'sub-DKI07_ses-1',
#     'sub-DKI07_ses-2',
#     'sub-DKI08_ses-1',
#     'sub-DKI09_ses-1',
#     'sub-DKI09_ses-2',
#     'sub-DKI09_ses-3',
#     'sub-DKI10_ses-1',
#     'sub-DKI10_ses-2',
#     'sub-DKI10_ses-3',
#     'sub-DKI11_ses-1',
#     'sub-DKI11_ses-2',
#     'sub-DKI11_ses-3',
#     'sub-DKI12_ses-1',
#     'sub-DKI12_ses-2',
#     'sub-DKI12_ses-3',
#     'sub-DKI13_ses-1',
#     'sub-DKI14_ses-1',
#     'sub-DKI14_ses-3',
#     'sub-DKI15_ses-1',
#     'sub-DKI15_ses-3',
#     'sub-DKI16_ses-3',
#     'sub-DKI17_ses-3',
#     'sub-DKI18_ses-3',
#     'sub-DKI19_ses-3',
#     'sub-DKI20_ses-3',
#     'sub-DKI21_ses-2',
#     'sub-DKI22_ses-5',
#     'sub-DKI22_ses-6',
#     'sub-DKI23_ses-5',
#     'sub-DKI23_ses-6',
#     'sub-DKI24_ses-5',
#     'sub-DKI24_ses-6',
#     'sub-DKI25_ses-5',
#     'sub-DKI25_ses-6',
#     'sub-DKI26_ses-5',
#     'sub-DKI26_ses-6',
#     'sub-DKI27_ses-5',
#     'sub-DKI27_ses-6',
#     'sub-DKI28_ses-5',
#     'sub-DKI28_ses-6',
#     'sub-DKI29_ses-5',
#     'sub-DKI29_ses-6',
#     'sub-DKI30_ses-5',
#     'sub-DKI30_ses-6',
#     'sub-DKI31_ses-5',
#     'sub-DKI31_ses-6',
#     'sub-DKI32_ses-5',
#     'sub-DKI32_ses-6',
#     'sub-DKI33_ses-5',
#     'sub-DKI33_ses-6',
#     'sub-DKI34_ses-5',
#     'sub-DKI34_ses-6',
#     'sub-DKI35_ses-5',
#     'sub-DKI36_ses-5',
#     'sub-DKI36_ses-6',
#     'sub-DKI37_ses-5',
#     'sub-DKI37_ses-6',
#     'sub-DKI38_ses-5',
#     'sub-DKI39_ses-5',
#     'sub-DKI39_ses-6',
#     'sub-DKI40_ses-5',
#     'sub-DKI40_ses-6',
#     'sub-DKI41_ses-5',
#     'sub-DKI41_ses-6',
#     'sub-DKI42_ses-2',
#     'sub-DKI43_ses-2',
#     'sub-DKI44_ses-2',
#     'sub-WT01_ses-1',
#     'sub-WT01_ses-2',
#     'sub-WT01_ses-3',
#     'sub-WT02_ses-1',
#     'sub-WT02_ses-2',
#     'sub-WT02_ses-3',
#     'sub-WT03_ses-1',
#     'sub-WT03_ses-2',
#     'sub-WT04_ses-1',
#     'sub-WT04_ses-2',
#     'sub-WT05_ses-1',
#     'sub-WT05_ses-2',
#     'sub-WT06_ses-1',
#     'sub-WT06_ses-2',
#     'sub-WT07_ses-1',
#     'sub-WT07_ses-2',
#     'sub-WT08_ses-1',
#     'sub-WT08_ses-2',
#     'sub-WT09_ses-1',
#     'sub-WT09_ses-2',
#     'sub-WT10_ses-1',
#     'sub-WT10_ses-2',
#     'sub-WT11_ses-3',
#     'sub-WT12_ses-3',
#     'sub-WT13_ses-3',
#     'sub-WT14_ses-3',
#     'sub-WT15_ses-3',
#     'sub-WT16_ses-3',
#     'sub-WT17_ses-3',
#     'sub-WT18_ses-5',
#     'sub-WT18_ses-6',
#     'sub-WT19_ses-5',
#     'sub-WT19_ses-6',
#     'sub-WT20_ses-5',
#     'sub-WT20_ses-6',
#     'sub-WT21_ses-5',
#     'sub-WT21_ses-6',
#     'sub-WT22_ses-5',
#     'sub-WT22_ses-6',
#     'sub-WT23_ses-5',
#     'sub-WT24_ses-5',
#     'sub-WT25_ses-5',
#     'sub-DKI01',
#     'sub-DKI02',
#     'sub-DKI03',
#     'sub-DKI04',
#     'sub-DKI05',
#     'sub-DKI06',
#     'sub-DKI07',
#     'sub-DKI08',
#     'sub-DKI09',
#     'sub-DKI10',
#     'sub-DKI11',
#     'sub-DKI12',
#     'sub-DKI13',
#     'sub-DKI14',
#     'sub-DKI15',
#     'sub-DKI16',
#     'sub-DKI17',
#     'sub-DKI18',
#     'sub-DKI19',
#     'sub-DKI20',
#     'sub-DKI21',
#     'sub-DKI22',
#     'sub-DKI23',
#     'sub-DKI24',
#     'sub-DKI25',
#     'sub-DKI26',
#     'sub-DKI27',
#     'sub-DKI28',
#     'sub-DKI29',
#     'sub-DKI30',
#     'sub-DKI31',
#     'sub-DKI32',
#     'sub-DKI33',
#     'sub-DKI34',
#     'sub-DKI35',
#     'sub-DKI36',
#     'sub-DKI37',
#     'sub-DKI38',
#     'sub-DKI39',
#     'sub-DKI40',
#     'sub-DKI41',
#     'sub-DKI42',
#     'sub-DKI43',
#     'sub-DKI44',
#     'sub-WT01',
#     'sub-WT02',
#     'sub-WT03',
#     'sub-WT04',
#     'sub-WT05',
#     'sub-WT06',
#     'sub-WT07',
#     'sub-WT08',
#     'sub-WT09',
#     'sub-WT10',
#     'sub-WT11',
#     'sub-WT12',
#     'sub-WT13',
#     'sub-WT14',
#     'sub-WT15',
#     'sub-WT16',
#     'sub-WT17',
#     'sub-WT18',
#     'sub-WT19',
#     'sub-WT20',
#     'sub-WT21',
#     'sub-WT22',
#     'sub-WT23',
#     'sub-WT24',
#     'sub-WT25',
#     'DKI',
#     'WT',
#     'sup-DKI_ses-1',
#     'sup-DKI_ses-2',
#     'sup-DKI_ses-3',
#     'sup-DKI_ses-5',
#     'sup-DKI_ses-6',
#     'sup-WT_ses-1',
#     'sup-WT_ses-2',
#     'sup-WT_ses-3',
#     'sup-WT_ses-5',
#     'sup-WT_ses-6'
# ]
