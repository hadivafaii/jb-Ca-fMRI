# %% [markdown]
# # (13) Variograms -- degree
#
# **Motivation**: Plot variograms for degree centrality, how much does this explain the observed cross-modality differences? <br>

# %%
# HIDE CODE


import os, sys
from IPython.display import display, Latex

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-Ca-fMRI/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-Ca-fMRI/figs')
tmp_dir = os.path.join(git_dir, 'jb-Ca-fMRI/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_Ca-fMRI'))
from figures.fighelper import *
from analysis.final import *
from utils.render import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
from tqdm.notebook import tqdm
# %matplotlib inline
set_style()

# %%
def default_props_anesth(
        num_k: int = 7,
        perc: int = 15,
        **kwargs, ):
    mice = Mice(512)
    mice.set_kws(
        desc_ca2='preproc',
        desc_bold='rabies-hp',
    )
    props_base = {
        'mice': mice,
        'num_k': num_k,
        'task': 'rest',
        'perc': f'p{perc}-sample',
        'metric': 'pearson',
        'sv_props': {
            'match_using': 'gam',
            'match_metric': 'euclidean'},
        'graph_type': 'real',
        'kw_kmeans': {'n_init': 100},
        'verbose': False,
    }
    kwargs = setup_kwargs(props_base, kwargs)
    props_ca = {'mode': 'ca2', **kwargs}
    return mice, props_ca


def default_props_awake(
        num_k: int = 7,
        perc: int = 15,
        **kwargs, ):
    mice = Mice(Config(
        nn=512,
        sub_ids=[2, 6, 7, 9, 10],
        ses_ids=[4],
        run_ids=range(1, 10 + 1),
    ))
    mice.set_kws(
        desc_ca2='awake',
        desc_bold='rabies-hp',
    )
    props_base = {
        'mice': mice,
        'num_k': num_k,
        'task': 'rest',
        'perc': f'p{perc}-sample',
        'metric': 'pearson',
        'sv_props': {
            'match_using': 'gam',
            'match_metric': 'euclidean'},
        'graph_type': 'real',
        'kw_kmeans': {'n_init': 100},
        'verbose': False,
    }
    kwargs = setup_kwargs(props_base, kwargs)
    props_ca = {'mode': 'ca2', **kwargs}
    return mice, props_ca


def _get_avg_deg_ca(mice):
    deg = {}
    for b in bands:
        mice.set_kws(band_ca2=b)
        d = collect_degrees_lite(
            mice=mice,
            mode='ca2',
            rho=0.15,
            filter_isolated=True,
        )
        x = np.stack(list(d.values()))
        deg[b] = bn.nanmean(x, 0)
    deg = {
        f"{bands[b]}\n{b}": d
        for b, d in deg.items()
    }
    return deg

# %% [markdown]
# ## Prep

# %%
bs = Base(Mice(512), mode='ca2')
kws_show = show_kws(7)
bands = {
    (0.0, 5.0): 'Unfiltered',
    (0.01, 5.0): 'HP',
    (0.01, 0.5): CAS,
    (0.5, 5.0): CAF,
}
fig_dir = pjoin(fig_base_dir, 'rebuttal')
print(fig_dir)
# Out:
# /home/hadi/Dropbox/git/jb-Ca-fMRI/figs/rebuttal

# %% [markdown]
# ## Ca$^{2+}$

# %% [markdown]
# ### Awake

# %%
mice_awake, _ = default_props_awake()
mice_awake.kws
# Out:
# {
#     'task': 'rest',
#     'exclude': True,
#     'runs_only': True,
#     'band_ca2': (0.01, 5.0),
#     'band_bold': (0.01, 0.5),
#     'desc_ca2': 'awake',
#     'desc_bold': 'rabies-hp'
# }

# %%
deg_awake = _get_avg_deg_ca(mice_awake)
bs.show(deg_awake, vmin=0, vmax=160, cmap='coolwarm');

# %% [markdown]
# ### Anesth

# %%
mice_anesth, _ = default_props_anesth()
mice_anesth.kws
# Out:
# {
#     'task': 'rest',
#     'exclude': True,
#     'runs_only': True,
#     'band_ca2': (0.01, 5.0),
#     'band_bold': (0.01, 0.5),
#     'desc_ca2': 'preproc',
#     'desc_bold': 'rabies-hp'
# }

# %%
deg_anesth = _get_avg_deg_ca(mice_anesth)
bs.show(deg_anesth, vmin=0, vmax=160, cmap='coolwarm');

# %% [markdown]
# ## Bold-lite

# %%
mice = Mice(512)
mice.kws
# Out:
# {
#     'task': 'rest',
#     'exclude': True,
#     'runs_only': True,
#     'band_ca2': (0.01, 5.0),
#     'band_bold': (0.01, 0.5),
#     'desc_ca2': 'preproc',
#     'desc_bold': 'rabies-hp'
# }

# %%
deg_bold = collect_degrees_lite(
    mice=mice,
    mode='bold-lite',
    rho=0.15,
    filter_isolated=True,
)
deg_bold = bn.nanmean(np.stack(list(
    deg_bold.values())), 0)

# %%
vmax = np.nanmax(deg_bold)
vmax
# Out:
# 111.26168224299066

# %%
bs.show(deg_bold, vmin=0, vmax=vmax, cmap='coolwarm');

# %% [markdown]
# ## Variogram

# %%
ids_present = np.array(list(
    mice.node_lookup['ca2'].values()))

# %% [markdown]
# ### Pairwise distances

# %%
top, _ = mice.parcel.load_top_flat()
pixel_coords = unique_idxs(top)

com = {}
for i, p in pixel_coords.items():
    if i not in bs.id2n:
        continue
    points = np.array(list(zip(*np.unravel_index(
        p, top.shape))))
    com[i] = points.mean(0)
len(com)
# Out:
# 540

# %% [markdown]
# #### plot CoM, make sure correct

# %%
ii = ids_present[86]

# %%
points = np.array(list(zip(*np.unravel_index(
    pixel_coords[ii],
    top.shape,
))))

# %%
fig, axes = create_figure(1, 2, (4, 1.5), sharey='all', layout='constrained')
for i in range(2):
    sns.histplot(points[:, i], bins=20, color='dimgrey', ax=axes[i])
    axes[i].axvline(points.mean(0)[i], color='k', ls='--')
plt.show()

# %%
fig, ax = create_figure()
ax.imshow(mwh(np.isin(top, [0, ii]), top), cmap='Spectral')
ax.add_patch(matplotlib.patches.Circle(com[ii][::-1], radius=6, color='k'))
remove_ticks(ax)
plt.show()

# %% [markdown]
# ---
# ## Draft

# %%
distances = {
    (ii, jj): np.linalg.norm(com[ii] - com[jj])
    for ii, jj in itertools.combinations(com, 2)
}
len(distances)
# Out:
# 254541

# %%
sns.histplot(list(distances.values()), bins=100)
plt.show()

# %%
list(distances)[:5]
# Out:
# [(52, 53), (52, 55), (52, 56), (52, 57), (52, 59)]

# %%
df = []
for (ii, jj), d in tqdm(distances.items()):
    lr_i = mice.parcel(ii)['hemis']
    lr_j = mice.parcel(jj)['hemis']
    df.append({
        'hemis_1': [lr_i],
        'hemis_2': [lr_j],
        'cond': [
            'within' if lr_i == lr_j
            else 'across'],
        'd': [d],
    })
df = pd.DataFrame(merge_dicts(df))
# Out:
#   0%|          | 0/254541 [00:00<?, ?it/s]

# %%
sns.histplot(data=df, x='d', hue='cond', bins=90)
plt.show()

# %% [markdown]
# ## End draft
# ---

# %%
deg = {
    BOLD: deg_bold,
    CAS: deg_anesth[f"{CAS}\n(0.01, 0.5)"],
    CAF: deg_anesth[f"{CAF}\n(0.5, 5.0)"],
}

# %%
ids_present_left = mice.parcel.df.loc[
    (mice.parcel.df['hemis'] == 1) &
    (mice.parcel.df['id'].isin(com)),
    'id'
].values
len(ids_present_left)
# Out:
# 270

# %%
distances_left = {
    (i, j): np.linalg.norm(com[i] - com[j]) for i, j
    in itertools.combinations(ids_present_left, 2)
}
len(distances_left)
# Out:
# 36315

# %%
delta = 50

num = 100
span = np.linspace(
    min(distances_left.values()),
    max(distances_left.values()),
    num=num,
)
gamma = {
    k: np.zeros(num)
    for k in deg
}
for i0, h in enumerate(span):
    neighbors = dict(filter(
        lambda t: h - delta < t[1] < h + delta,
        distances_left.items(),
    ))
    for mode, d in deg.items():
        var = np_nans(len(neighbors))
        for ctr, (i, j) in enumerate(neighbors):
            xi = d[bs.id2n[i]]
            xj = d[bs.id2n[j]]
            var[ctr] = (xi - xj) ** 2
        var = np.nanmean(var)
        gamma[mode][i0] = var

# %%
pal = prepare_palette()

fig, axes = create_figure(1, 3, (8, 1.6), layout='constrained')
for i, mode in enumerate(gamma):
    axes[i].plot(
        span,
        gamma[mode],
        color=pal[mode],
        label=mode,
        lw=3,
    )
    axes[i].legend()

fig.savefig(
    pjoin(fig_dir, f"variogram_degree.pdf"),
    # bbox_extra_artists=[s],
    bbox_inches='tight',
    # dpi=200,
)
plt.show()

# %% [markdown]
# ## Degree rank

# %% [markdown]
# ### BOLD

# %%
deg_bold = collect_degrees_lite(
    mice=mice,
    mode='bold-lite',
    rho=0.15,
    filter_isolated=True,
)
deg_bold = np.stack(list(
    deg_bold.values()))

dr_bold = np_nans(deg_bold.shape)
for i, x in enumerate(deg_bold):
    good = np.isfinite(x)
    if not good.sum():
        continue
    _ranked = sp_stats.rankdata(x[good])
    _ranked /= np.nanmax(_ranked)
    dr_bold[i, good] = _ranked
dr_bold = bn.nanmean(dr_bold, 0)

# %% [markdown]
# ### CAS

# %%
mice_anesth.set_kws(band_ca2=(0.01, 0.5))
deg_cas = collect_degrees_lite(
    mice=mice_anesth,
    mode='ca2',
    rho=0.15,
    filter_isolated=True,
)
deg_cas = np.stack(list(
    deg_cas.values()))

dr_cas = np_nans(deg_cas.shape)
for i, x in enumerate(deg_cas):
    good = np.isfinite(x)
    if not good.sum():
        continue
    _ranked = sp_stats.rankdata(x[good])
    _ranked /= np.nanmax(_ranked)
    dr_cas[i, good] = _ranked
dr_cas = bn.nanmean(dr_cas, 0)

# %% [markdown]
# ### CAF

# %%
mice_anesth.set_kws(band_ca2=(0.5, 5.0))
deg_caf = collect_degrees_lite(
    mice=mice_anesth,
    mode='ca2',
    rho=0.15,
    filter_isolated=True,
)
deg_caf = np.stack(list(
    deg_caf.values()))

dr_caf = np_nans(deg_caf.shape)
for i, x in enumerate(deg_caf):
    good = np.isfinite(x)
    if not good.sum():
        continue
    _ranked = sp_stats.rankdata(x[good])
    _ranked /= np.nanmax(_ranked)
    dr_caf[i, good] = _ranked
dr_caf = bn.nanmean(dr_caf, 0)

# %%
dr = {
    'BOLD': dr_bold,
    'CAS': dr_cas,
    'CAF': dr_caf,
}

# %%
{k: (np.nanmin(v), np.nanmax(v)) for k, v in dr.items()}
# Out:
# {
#     'BOLD': (0.1636030872329026, 0.7618670209984403),
#     'CAS': (0.07455426045514849, 0.9319673110142711),
#     'CAF': (0.009846819005735, 0.964751401485692)
# }

# %%
bs.show(dr, vmin=0, vmax=0.9, figsize=(6, 9), cmap='coolwarm', cbar=True);

# %%
delta = 50

num = 100
span = np.linspace(
    min(distances_left.values()),
    max(distances_left.values()),
    num=num,
)
gamma = {
    k: np.zeros(num)
    for k in dr
}
for i0, h in enumerate(span):
    neighbors = dict(filter(
        lambda t: h - delta < t[1] < h + delta,
        distances_left.items(),
    ))
    for mode, d in dr.items():
        var = np_nans(len(neighbors))
        for ctr, (i, j) in enumerate(neighbors):
            xi = d[bs.id2n[i]]
            xj = d[bs.id2n[j]]
            var[ctr] = (xi - xj) ** 2
        var = np.nanmean(var)
        gamma[mode][i0] = var

# %%
translation = {'BOLD': BOLD, 'CAS': CAS, 'CAF': CAF}

# %%
pal = prepare_palette()

fig, ax = create_figure(1, 1, (4.5, 2.2), sharey='all', layout='constrained')
for i, mode in enumerate(gamma):
    ax.plot(
        span,
        gamma[mode],
        color=pal[translation[mode]],
        label=translation[mode],
        lw=3,
    )
ax.legend()
ax.set_ylabel(r'$\gamma$', fontsize=13)
ax.set_xlabel('Distance ' + r"$\left(\times 10^{-2} \, \mathrm{mm}\right)$")
move_legend(ax, (1., 1.03))
ax.grid()

fig.savefig(
    pjoin(fig_dir, f"variogram_degree_rank_together.pdf"),
    # bbox_extra_artists=[s],
    bbox_inches='tight',
    # dpi=200,
)
plt.show()

# %%
save_obj(
    obj=dr,
    file_name='degree_ranks',
    save_dir=tmp_dir,
    mode='npy',
)
# Out:
# [PROGRESS] 'degree_ranks.npy' saved at
# /home/hadi/Dropbox/git/jb-Ca-fMRI/tmp
# '/home/hadi/Dropbox/git/jb-Ca-fMRI/tmp/degree_ranks.npy'

# %%
save_obj(
    obj=distances_left,
    file_name='euclidean_dists_left_hemis',
    save_dir=tmp_dir,
    mode='npy',
)
# Out:
# [PROGRESS] 'euclidean_dists_left_hemis.npy' saved at
# /home/hadi/Dropbox/git/jb-Ca-fMRI/tmp
# '/home/hadi/Dropbox/git/jb-Ca-fMRI/tmp/euclidean_dists_left_hemis.npy'
