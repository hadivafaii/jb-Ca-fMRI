# %% [markdown]
# # Jun 27th, 2022 (Carto not working: 128)
#
# **Motivation**:  <br>

# %%
# HIDE CODE


import os
import sys
from pprint import pprint
from copy import deepcopy as dc
from os.path import join as pjoin
from scipy.ndimage import gaussian_filter
from IPython.display import display, IFrame, HTML

# tmp & extras dir
git_dir = pjoin(os.environ['HOME'], 'Dropbox/git')
extras_dir = pjoin(git_dir, 'jb-Ca-fMRI/_extras')
fig_base_dir = pjoin(git_dir, 'jb-Ca-fMRI/figs')
tmp_dir = pjoin(git_dir, 'jb-Ca-fMRI/tmp')

# GitHub
sys.path.insert(0, pjoin(git_dir, '_Ca-fMRI'))
from model.configuration import Config
from model.mouse import Mice
from analysis.bootstrap import *
from analysis.network import *
from utils.render import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
from tqdm.notebook import tqdm
# %matplotlib inline
set_style()

# %%
# HIDE CODE


def plot_cartography(
    df: pd.DataFrame,
    palette: Dict[str, str],
    x_var: str = 'ent',
    y_var: str = 'deg',
    xlim: Tuple[float, float] = None,
    ylim: Tuple[float, float] = None,
    hue: str = 'oc_idx',
    grid: bool = True,
    display: bool = True,
    leg_size: float = 14,
    size: float = 7,
    scatter_kws: dict = None,
    density_kws: dict = None,
    median_kws: dict = None, ):
    
    scatter_kws = scatter_kws if scatter_kws else {
        's': 120,
        'alpha': 0.9,
        'edgecolor': 'dimgrey',
    }
    density_kws = density_kws if density_kws else {
        'lw': 2,
        'fill': True,
        'alpha': 0.5,
    }
    median_kws = median_kws if median_kws else {
        'lw': 1.5,
        'ls': '--',
        'zorder': 0,
        'alpha': 1.0,
        'c': sns.color_palette('deep')[7],
    }
    
    set_style('ticks')
    jg = sns.JointGrid(
        data=df,
        x=x_var,
        y=y_var,
        hue=hue,
        size=size,
        palette=palette,
        xlim=xlim,
        ylim=ylim,
        space=0.0,
    )
    # joint: scatter
    jg.plot_joint(
        sns.scatterplot,
        hue=hue,
        **scatter_kws,
    )
    # margnials: density
    jg.plot_marginals(
        sns.kdeplot,
        **density_kws,
    )
    # medians
    for name in [x_var, y_var]:
        x = df[name].median()
        lbl = f"median {name}: {x:.2f}"
        if name == x_var:
            jg.refline(x=x, label=lbl, **median_kws)
        else:
            jg.refline(y=x, label=lbl, **median_kws)
    # legend
    jg.ax_joint.legend(loc='upper left', prop={'size': leg_size})
    leg = jg.ax_joint.get_legend()
    if leg is not None:
        plt.setp(leg, bbox_to_anchor=(1.3, 1.0))
    
    if grid:
        jg.ax_joint.grid()
    
    if display:
        plt.show()
    else:
        plt.close()
    return jg

# %% [markdown]
# ## Prepare (128)

# %%
mice = Mice(128)

_BOLD = 'BOLD'
_CAS = r'Ca$^{2\!\!+}$' + ' (slow)'
_CAF = r'Ca$^{2\!\!+}$' + ' (fast)'
mako = sns.color_palette('mako', as_cmap=True)
rocket = sns.color_palette('rocket', as_cmap=True)
pal = {_BOLD: rocket(0.6), _CAS: mako(0.6), _CAF: to_rgb('C8')} # mako(0.3)}

# %%
task = 'rest'

num_k, p = 10, 20
perc = f'p{p}-sample'
props_base = {
    'kw_kmeans': {'n_init': 100},
    'perc': perc,
    'num_k': num_k,
    'mice': mice,
    'task': task,
    'metric': 'pearson',
    'match_using': 'gam',
    'match_metric': 'euclidean',
    'graph_type': 'real',
    'verbose': False,
}
props_ca = {'mode': 'ca2', **props_base}
props_bo = {'mode': 'bold-lite', **props_base}

bs = Base(**props_ca)
bt_bo = BootStrap(**props_bo)

mice.setup_func_data(task, band_ca=(0.01, 0.5))
bt_cas = BootStrap(**props_ca)

mice.setup_func_data(task, band_ca=0.5)
bt_caf = BootStrap(**props_ca)

# %% [markdown]
# ## How mu = 0.003, alpha = 0.05 looks: raw vs. prune

# %%
_ = bs.show(
    data={'raw': avg(bt_bo.run_pi), 'prune(SciPy)': avg(bt_bo.pi_prune)},
    figsize=(40, 6),
    ylabel_fontsize=20,
)

# %%
_ = bs.show(
    data={'raw': avg(bt_cas.run_pi), 'prune(SciPy)': avg(bt_cas.pi_prune)},
    figsize=(40, 6),
    ylabel_fontsize=20,
)

# %%
_ = bs.show(
    data={'raw': avg(bt_caf.run_pi), 'prune(SciPy)': avg(bt_caf.pi_prune)},
    figsize=(40, 6),
    ylabel_fontsize=20,
)

# %%
[e[-1] for e in bs.pi_symmetry_score(avg(bt_cas.pi_prune))]
# Out:
# [0.978, 0.961]

# %%
[e[-1] for e in bs.pi_symmetry_score(avg(bt_cas.run_pi))]
# Out:
# [0.985, 0.966]

# %% [markdown]
# ## Members: various $\mu$

# %%
se, f = bt_bo.fit_boot(n_resamples=int(1e5))
f
# Out:
# 'se-BCa_group-pi_1.0e+05'

# %%
pi = avg(bt_bo.pi_prune)
members = np.zeros(pi.shape)
alpha = 0.05

mu_vals = [0.05] + [i / bt_bo.num_k for i in [1, 3, 5]]
for mu in mu_vals:
    reject, pvals = bt_bo.ttest(se, pi, mu=mu, alpha=alpha)
    members[reject == 1] += 1
members /= np.nanmax(members)

mu_vals
# Out:
# [0.05, 0.1, 0.3, 0.5]

# %%
_ = bs.show(
    data=members.astype(float),
    vmin=0.1,
    vmax=1.0,
    cmap='Spectral',
    coarse=False,
    width=0.001,
    add_disjoint=False,
    figsize=(40, 8),
)

# %%
se, f = bt_cas.fit_boot(n_resamples=int(1e5))
f
# Out:
# 'se-BCa_group-pi_1.0e+05'

# %%
pi = avg(bt_cas.pi_prune)
members = np.zeros(pi.shape)
alpha = 0.05

mu_vals = [0.05] + [i / bt_cas.num_k for i in [1, 3, 5]]
for mu in mu_vals:
    reject, pvals = bt_cas.ttest(se, pi, mu=mu, alpha=alpha)
    members[reject == 1] += 1
members /= np.nanmax(members)

mu_vals
# Out:
# [0.05, 0.1, 0.3, 0.5]

# %%
_ = bs.show(
    data=members.astype(float),
    vmin=0.1,
    vmax=1.0,
    cmap='Spectral',
    coarse=False,
    width=0.001,
    add_disjoint=False,
    figsize=(40, 8),
)

# %%
se, f = bt_caf.fit_boot(n_resamples=int(1e5))
f
# Out:
# 'se-BCa_group-pi_1.0e+05'

# %%
pi = avg(bt_caf.pi_prune)
members = np.zeros(pi.shape)
alpha = 0.05

mu_vals = [0.05] + [i / bt_caf.num_k for i in [1, 3, 5]]
for mu in mu_vals:
    reject, pvals = bt_caf.ttest(se, pi, mu=mu, alpha=alpha)
    members[reject == 1] += 1
members /= np.nanmax(members)

mu_vals
# Out:
# [0.05, 0.1, 0.3, 0.5]

# %%
_ = bs.show(
    data=members.astype(float),
    vmin=0.1,
    vmax=1.0,
    cmap='Spectral',
    coarse=False,
    width=0.001,
    add_disjoint=False,
    figsize=(40, 8),
)

# %% [markdown]
# ## Explore degree a bit

# %%
fig, axes = create_figure(2, 2, (11, 7))

bins = np.linspace(0, 300, 301)
sns.histplot(bt_cas.run_deg[np.isfinite(bt_cas.run_deg)], bins=bins, ax=axes[0, 0])
sns.histplot(bt_cas.run_deg[np.nonzero(bt_cas.run_deg)], bins=bins, ax=axes[0, 1])

bins = np.linspace(0, 300, 31)
sns.histplot(bt_cas.run_deg[np.isfinite(bt_cas.run_deg)], bins=bins, ax=axes[1, 0])
sns.histplot(bt_cas.run_deg[np.nonzero(bt_cas.run_deg)], bins=bins, ax=axes[1, 1])

_x = np.nanmedian(bt_cas.run_deg[np.isfinite(bt_cas.run_deg)])
axes[0, 0].axvline(_x, color='k', ls='--', label=f'median: {_x:0.2f}')
_x = np.nanmean(bt_cas.run_deg[np.isfinite(bt_cas.run_deg)])
axes[0, 0].axvline(_x, color='r', ls='--', label=f'mean: {_x:0.2f}')
    
_x = np.nanmedian(bt_cas.run_deg[np.nonzero(bt_cas.run_deg)])
axes[0, 1].axvline(_x, color='k', ls='--', label=f'median: {_x:0.2f}')
_x = np.nanmean(bt_cas.run_deg[np.nonzero(bt_cas.run_deg)])
axes[0, 1].axvline(_x, color='r', ls='--', label=f'mean: {_x:0.2f}')
    
for ax in axes[0].flat:
    ax.legend()
    
plt.show()

# %%
deg = np.concatenate([
    np.expand_dims(avg(bt_bo.run_deg, 1), 0),
    np.expand_dims(avg(bt_cas.run_deg, 1), 0),
    np.expand_dims(avg(bt_caf.run_deg, 1), 0),
])
_ = bs.show(
    data=deg,
    figsize=(13.5, 3.1),
    vmin=np.nanmin(deg),
    vmax=np.nanmax(deg),
    mask_thresh=0.001,
    add_disjoint=False,
    cmap='coolwarm',
    cbar=True,
)
for i in range(3):
    _ = bs.show(
        data=deg[i],
        figsize=(13.5, 3.1),
        vmin=np.nanmin(deg[i]),
        vmax=np.nanmax(deg[i]),
        mask_thresh=0.001,
        add_disjoint=False,
        cmap='coolwarm',
        cbar=True,
    )

# %% [markdown]
# ### See if mega animal helps (deg)

# %%
x = 'sub-SLC_task-rest_space-CCF3d_bold.npy'
x = pjoin(mice.cfg.bold_dir, x)
x = np.load(x)

# %%
a, p = get_adj_mat(x, 'pearson')

# %%
create_figure()
plt.imshow(a, cmap='nipy_spectral')
plt.colorbar()

create_figure()
plt.imshow(p)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar object at 0x7f4b6881de20>

# %%
sns.histplot(a[a.nonzero()])
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
b = a.copy()
b[b < 0] = 0

# %%
create_figure()
plt.imshow(b, cmap='nipy_spectral')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar object at 0x7f4b63b4a0d0>

# %%
rho = [0.05, 0.1, 0.15, 0.20, 0.25, 0.30, 0.35]
thresholds = calculate_threshold(b, rho, verbose=True)
thresholds = dict(zip(rho, thresholds))
# Out:
# threshold = 0.078   /   density:  requested = 0.05000, result = 0.05000;
# threshold = 0.051   /   density:  requested = 0.10000, result = 0.10000;
# threshold = 0.040   /   density:  requested = 0.15000, result = 0.15000;
# threshold = 0.034   /   density:  requested = 0.20000, result = 0.20000;
# threshold = 0.029   /   density:  requested = 0.25000, result = 0.25000;
# threshold = 0.025   /   density:  requested = 0.30000, result = 0.30000;
# threshold = 0.022   /   density:  requested = 0.35000, result = 0.35000;
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>

# %%
c = b.copy()
c[c <= thresholds[0.25]] = 0

# %%
g = nx.from_numpy_matrix(c)
nx.density(g)
# Out:
# 0.25

# %%
deg_binary = c.sum(0)
deg_weighted = b.sum(0)

plt.plot(deg_weighted, label='weighted')
plt.plot(deg_binary, label='binary')
plt.legend()
# Out:
# <matplotlib.legend.Legend object at 0x7f4b63ae4dc0>

# %%
bs2 = Base(mice=mice, mode='bold')

# %%
_ = bs2.show(
    data=deg_binary,
    vmin=deg_binary.min(),
    vmax=60,
    figsize=(8, 5),
    contour=False,
    cbar=True,
    cmap='coolwarm',
    add_disjoint=False,
)
_ = bs2.show(
    data=deg_binary,
    vmin=deg_binary.min(),
    vmax=60,
    figsize=(10, 4),
    contour=False,
    cbar=True,
    cmap='coolwarm',
    proj='flat',
    add_disjoint=False,
)

# %%
_ = bs2.show(
    data=deg_weighted,
    vmin=deg_weighted.min(),
    vmax=60,
    figsize=(8, 5),
    contour=False,
    cbar=True,
    cmap='coolwarm',
    add_disjoint=False,
)
_ = bs2.show(
    data=deg_weighted,
    vmin=deg_weighted.min(),
    vmax=60,
    figsize=(10, 4),
    contour=False,
    cbar=True,
    cmap='coolwarm',
    proj='flat',
    add_disjoint=False,
)

# %%
bins = np.linspace(0, 80, 17)
sns.histplot(avg(bt_caf.run_deg, 1), color=pal[_CAF], bins=bins, label=_CAF)
sns.histplot(avg(bt_cas.run_deg, 1), color=pal[_CAS], bins=bins, label=_CAS)
sns.histplot(avg(bt_bo.run_deg, 1), color=pal[_BOLD], bins=bins, label=_BOLD)
plt.legend();

# %%
# %%time

df = []
for mode, bt in {_BOLD: bt_bo, _CAS: bt_cas, _CAF: bt_caf}.items():
    _df = bt.mk_cartography_df(affil=bs.affil_included)
    _df['mode'] = mode
    df.append(_df)
df = pd.concat(df, axis=0)
# Out:
# CPU times: user 1min 25s, sys: 883 ms, total: 1min 26s
# Wall time: 1min 26s

# %%
fig, axes = create_figure(1, 3, (13, 4.5), 'all', 'all')

for ax, mode in zip(axes.flat, df['mode'].unique()):
    _df = df.loc[df['mode'] == mode]
    good = np.logical_and(np.isfinite(_df['p_ent']), np.isfinite(_df['p_deg']))
    pearson_r, pval = sp_stats.pearsonr(_df['p_ent'][good], _df['p_deg'][good])
    title = f"mode = {mode}\n"
    title += f"r = {pearson_r:0.2f}, p = {pval:0.2g}"
    
    sns.regplot(_df['p_ent'][good], _df['p_deg'][good], color=pal[mode], ax=ax)
    ax.set_title(title, fontsize=13)
    ax.set_aspect('equal')
    ax.set_xlabel('Entropy t-statistic percentile', fontsize=14)
axes[0].set_ylabel('Degree t-statistic percentile', fontsize=14)
plt.show()

# %%
fig, axes = create_figure(2, 3, (13, 9), 'all', 'all')

for i, (mode1, mode2) in enumerate(itertools.combinations(pal, 2)):
    _df1 = df.loc[df['mode'] == mode1]
    _df2 = df.loc[df['mode'] == mode2]
    
    ax = axes[0, i]
    good = np.logical_and(
        np.isfinite(_df1['p_ent']),
        np.isfinite(_df2['p_ent']),
    )
    pearson_r, pval = sp_stats.pearsonr(
        _df1['p_ent'][good],
        _df2['p_ent'][good],
    )
    title = f"Measure = Entropy\n"
    title += f"r = {pearson_r:0.2f}, p = {pval:0.2g}"
    ax.set_title(title, fontsize=15)
    sns.regplot(_df1['p_ent'], _df2['p_ent'], ax=ax)
    
    ax.set_xlabel(mode1)
    ax.set_ylabel(mode2)

    
    ax = axes[1, i]
    good = np.logical_and(
        np.isfinite(_df1['p_deg']),
        np.isfinite(_df2['p_deg']),
    )
    pearson_r, pval = sp_stats.pearsonr(
        _df1['p_deg'][good],
        _df2['p_deg'][good],
    )
    title = f"Measure = Degree\n"
    title += f"r = {pearson_r:0.2f}, p = {pval:0.2g}"
    ax.set_title(title, fontsize=15)
    sns.regplot(_df1['p_deg'], _df2['p_deg'], ax=ax)
    
    ax.set_xlabel(mode1)
    ax.set_ylabel(mode2)

plt.show()

# %%
xy = {
    k: np.concatenate([
        np.expand_dims(df.loc[df['mode'] == k, 'p_ent'].values, 0),
        np.expand_dims(df.loc[df['mode'] == k, 'p_deg'].values, 0),
    ]) for k in df['mode'].unique()
}

# %%
_ = bs.show(
    data=xy,
    figsize=(8, 9),
    vmin=0,
    vmax=100,
    mask_thresh=0.00001,
    add_disjoint=False,
    cmap='coolwarm',
    cbar=True,
)

# %%
delta = {
    f"{k1}_vs_{k2}": np.linalg.norm(xy[k1] - xy[k2], ord=2, axis=0)
    for k1, k2 in itertools.combinations(xy, 2)
}
delta = {k: v / np.linalg.norm([200], ord=2) for k, v in delta.items()}

# %%
fig, axes = create_figure(1, 3, (13, 4))
for ax, (k, v) in zip(axes.flat, delta.items()):
    sns.histplot(v, bins=np.linspace(0, 1, 21), ax=ax)
    ax.axvline(bn.nanmean(v), color='k', ls='--', label=f"mean = {bn.nanmean(v):0.2g}")
    ax.set_title(k)
    ax.legend()
plt.show()

# %%
vmin = np.nanmin([np.nanmin(v) for v in delta.values()])
vmax = np.nanmax([np.nanmax(v) for v in delta.values()])
vmin, vmax
# Out:
# (0.006985657282722356, 0.4899584155906795)

# %%
_ = bs.show(
    data=delta,
    vmin=0,
    vmax=0.6,
    mask_thresh=0.0001,
    thres=-np.inf,
    cmap='hot',
    cbar=True,
    add_disjoint=False,
    figsize=(5, 10),
)

# %%
fig, axes = create_figure(1, 3, (13.5, 4.5))

for ax, mode in zip(axes.flat, df['mode'].unique()):
    _df = df.loc[
        (df['mode'] == mode) &
        (~df['affil'].isin(['Auditory', 'Lateral']))
    ]
    sns.scatterplot(
        data=_df,
        x='p_ent',
        y='p_deg',
        hue='affil',
        palette=bs.affil['colors'],
        legend=True if mode == list(pal)[-1] else False,
        ax=ax,
    )
    ax.set_ylabel('')
    ax.set_xlabel('Entropy t-statistic percentile', fontsize=14)
axes[0].set_ylabel('Degree t-statistic percentile', fontsize=14)
plt.show()

# %%
fig, axes = create_figure(2, 3, (13.5, 9))

for i, mode in enumerate(df['mode'].unique()):
    _df = df.loc[
        (df['mode'] == mode) &
        (~df['affil'].isin(['Auditory', 'Lateral']))
    ]
    ax = axes[0, i]
    sns.scatterplot(
        data=_df,
        x='ent',
        y='deg',
        hue='affil',
        palette=bs.affil['colors'],
        legend=True if mode == list(pal)[-1] else False,
        ax=ax,
    )
    ax.set_ylabel('')
    ax.set_xlabel('Entropy', fontsize=14)
    
    ax = axes[1, i]
    sns.scatterplot(
        data=_df,
        x='p_ent',
        y='p_deg',
        hue='affil',
        palette=bs.affil['colors'],
        legend=True if mode == list(pal)[-1] else False,
        ax=ax,
    )
    ax.set_ylabel('')
    ax.set_xlabel('Entropy t-statistic percentile', fontsize=14)
    
axes[0, 0].set_ylabel('Degree', fontsize=14)
axes[0, 1].set_ylabel('Degree t-statistic percentile', fontsize=14)
plt.show()

# %%
list(bs.affil)
# Out:
# [
#     'cmap',
#     'colors',
#     'obj_top',
#     'obj_flat',
#     'aff_top',
#     'aff_flat',
#     'regions_l',
#     'regions_r',
#     'affiliation',
#     'regions_affil',
#     'regions_affil_max'
# ]

# %%
a = bs.affil['obj_top'].copy()
for i, idx in enumerate(np.unique(a[a.nonzero()])):
    a[a == idx] = i + 1

# %%
fig, axes = create_figure(1, 2, (6, 4))
axes[0].imshow(mwh(a == 0, a), cmap='tab20c')
axes[1].imshow(mwh(bs.affil['aff_top'] == 0, bs.affil['aff_top']), cmap=bs.affil['cmap'])
remove_ticks(axes)
plt.show()

# %% [markdown]
# ## Explore entropy a little

# %%
a = np.concatenate([
    np.expand_dims(df.loc[df['mode'] == k, 'ent'].values, 0)
    for k in df['mode'].unique()
])
_ = bs.show(
    data=a,
    figsize=(13, 2.8),
    vmin=np.nanmin(a),
    vmax=np.nanmax(a),
    mask_thresh=1e-20,
    add_disjoint=False,
    cmap='icefire',
    cbar=True,
)

# %%
_ = bs.show(
    data=a[0],
    figsize=(4, 2.8),
    vmin=np.nanmin(a[0]),
    vmax=np.nanmax(a[0]),
    mask_thresh=1e-20,
    add_disjoint=False,
    cmap='icefire',
    cbar=True,
)

# %%
b = np.concatenate([
    np.expand_dims(sp_stats.entropy(avg(bt_bo.pi_prune), axis=-2), 0),
    np.expand_dims(sp_stats.entropy(avg(bt_cas.pi_prune), axis=-2), 0),
    np.expand_dims(sp_stats.entropy(avg(bt_caf.pi_prune), axis=-2), 0),
]) / np.log(num_k)
_ = bs.show(
    data=b,
    figsize=(13, 2.8),
    vmin=np.nanmin(b),
    vmax=np.nanmax(b),
    mask_thresh=1e-20,
    add_disjoint=False,
    cmap='icefire',
    cbar=True,
)

# %%
b = sp_stats.entropy(avg(bt_bo.pi_prune), axis=-2) / np.log(num_k)
_ = bs.show(
    data=b,
    figsize=(13, 2.8),
    vmin=np.nanmin(b),
    vmax=np.nanmax(b),
    mask_thresh=1e-20,
    add_disjoint=False,
    cmap='icefire',
    cbar=True,
)

# %%
sns.regplot(a[1], avg(bt_cas.run_deg, 1))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Finally, carto

# %%
df = bt_cas.mk_cartography_df()

# %%
xlim = (0, 0.75)
ylim = (0, 55)

jg = plot_cartography(
    df=df,
    palette=bs.affil['colors'],
    hue='affil',
    xlim=xlim,
    ylim=ylim,
    grid=True,
)

# %%
xlim = (0, 70)
ylim = (0, 50)

jg = plot_cartography(
    df=df,
    palette=bs.affil['colors'],
    hue='affil',
    x_var='t_ent',
    y_var='t_deg',
    xlim=xlim,
    ylim=ylim,
    grid=True,
)

# %%
vlines = [df['ent'].quantile(q) for q in [0.25, 0.5, 0.75]]
hlines = [df['deg'].quantile(q) for q in [0.25, 0.5, 0.75]]

# %%
tval = sp_stats.t.ppf((1 + 0.95) / 2, 9)
tval
# Out:
# 2.2621571627409915

# %%
fig, ax = create_figure(1, 1, (8, 6), 'all', 'all')

for x in vlines:
    ax.axvline(x, color='dimgrey', ls='--', lw=0.8, zorder=0)
for y in hlines:
    ax.axhline(y, color='dimgrey', ls='--', lw=0.8, zorder=0)

sns.scatterplot(
    data=df,
    x='ent',
    y='deg',
    hue='affil',
    palette=bs.affil['colors'],
    s=110,
    alpha=0.8,
    ax=ax,
)
ax.set_title('ca2', fontsize=20, y=1.02)

ax.errorbar(
    x=df['ent'].values,
    y=df['deg'].values,
    xerr=tval * df['se_ent'].values,
    yerr=tval * df['se_deg'].values,
    color='dimgrey',
    errorevery=1,
    capsize=6,
    alpha=0.12,
    ls='none',
    zorder=0,
)

xlim = (0, 0.8)
ylim = (0, 60)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
aspect = (max(xlim) - min(xlim)) / (max(ylim) - min(ylim))
ax.set_aspect(aspect, adjustable='box')
# name = 'carto-group'
# figname = f"{name}.pdf"
# fig.savefig(pjoin(save_dir, figname), **fig_kws)


plt.show()

# %%
df = bt_bo.mk_cartography_df()

# %%
xlim = (0.2, 0.8)
ylim = (10, 50)

jg = plot_cartography(
    df=df,
    palette=bs.affil['colors'],
    hue='affil',
    xlim=xlim,
    ylim=ylim,
    grid=True,
)

# %%
xlim = (0, 60)
ylim = (0, 50)

jg = plot_cartography(
    df=df,
    palette=bs.affil['colors'],
    hue='affil',
    x_var='t_ent',
    y_var='t_deg',
    xlim=xlim,
    ylim=ylim,
    grid=True,
)

# %%
vlines = [df['ent'].quantile(q) for q in [0.25, 0.5, 0.75]]
hlines = [df['deg'].quantile(q) for q in [0.25, 0.5, 0.75]]

# %%
fig, ax = create_figure(1, 1, (8, 6), 'all', 'all')

for x in vlines:
    ax.axvline(x, color='dimgrey', ls='--', lw=0.8, zorder=0)
for y in hlines:
    ax.axhline(y, color='dimgrey', ls='--', lw=0.8, zorder=0)

sns.scatterplot(
    data=df,
    x='ent',
    y='deg',
    hue='affil',
    palette=bs.affil['colors'],
    s=110,
    alpha=0.8,
    ax=ax,
)
ax.set_title('BOLD', fontsize=20, y=1.02)

ax.errorbar(
    x=df['ent'].values,
    y=df['deg'].values,
    xerr=tval * df['se_ent'].values,
    yerr=tval * df['se_deg'].values,
    color='dimgrey',
    errorevery=1,
    capsize=6,
    alpha=0.12,
    ls='none',
    zorder=0,
)

xlim = (0.2, 0.8)
ylim = (5, 55)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
aspect = (max(xlim) - min(xlim)) / (max(ylim) - min(ylim))
ax.set_aspect(aspect, adjustable='box')
# name = 'carto-group'
# figname = f"{name}.pdf"
# fig.savefig(pjoin(save_dir, figname), **fig_kws)


plt.show()
