# %% [markdown]
# # Jun ??th, 2022 (ttest + ovp score new)
#
# **Motivation**: This allows to prune + calculate ovp scores in a much more principled way <br>

# %%
# HIDE CODE


import os
import sys
from pprint import pprint
from copy import deepcopy as dc
from os.path import join as pjoin
from scipy.ndimage import gaussian_filter
from IPython.display import display, IFrame, HTML

# tmp & extras dir
git_dir = pjoin(os.environ['HOME'], 'Dropbox/git')
extras_dir = pjoin(git_dir, 'jb-Ca-fMRI/_extras')
fig_base_dir = pjoin(git_dir, 'jb-Ca-fMRI/figs')
tmp_dir = pjoin(git_dir, 'jb-Ca-fMRI/tmp')

# GitHub
sys.path.insert(0, pjoin(git_dir, '_Ca-fMRI'))
from model.configuration import Config
from model.mouse import Mice
from analysis.network import *
from analysis.group import *
from utils.render import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
from tqdm.notebook import tqdm
# %matplotlib inline
set_style()

# %% [markdown]
# ## Prepare

# %%
mice = Mice(512)

_BOLD = 'BOLD'
_CAS = r'Ca$^{2\!\!+}$' + ' (slow)'
_CAF = r'Ca$^{2\!\!+}$' + ' (fast)'
mako = sns.color_palette('mako', as_cmap=True)
rocket = sns.color_palette('rocket', as_cmap=True)
pal = {_BOLD: rocket(0.6), _CAS: mako(0.6), _CAF: to_rgb('C8')} # mako(0.3)}

# %%
task = 'rest'
b = (0.01, 0.5)
mice.setup_func_data(task, band_ca=b)

num_k, p = 7, 20
perc = f'p{p}-sample'
props_base = {
    'kw_kmeans': {'n_init': 100},
    'perc': perc,
    'num_k': num_k,
    'mice': mice,
    'task': task,
    'metric': 'pearson',
    'match_using': 'gam',
    'match_metric': 'euclidean',
    'graph_type': 'real',
    'verbose': False,
}
props_ca = {'mode': 'ca2', **props_base}
props_bo = {'mode': 'bold-lite', **props_base}

gr_ca = Group(**props_ca).fit_group()
gr_bo = Group(**props_bo).fit_group()

# %%
gr_ca.avg()

# %%
gr_ca.pi_symmetry_score()
# Out:
# (
#     {
#         1: 0.959,
#         2: 0.991,
#         3: 0.993,
#         4: 0.993,
#         5: 0.983,
#         6: 0.994,
#         7: 0.984,
#         -1: 0.985
#     },
#     {
#         1: 0.978,
#         2: 0.993,
#         3: 0.982,
#         4: 0.967,
#         5: 0.978,
#         6: 0.982,
#         7: 0.974,
#         -1: 0.979
#     }
# )

# %%
pi_prune = gr_ca.prune()
pi = avg(pi_prune)

# %%
gr_ca.pi_symmetry_score(pi)
# Out:
# (
#     {
#         1: 0.921,
#         2: 0.987,
#         3: 0.991,
#         4: 0.984,
#         5: 0.973,
#         6: 0.991,
#         7: 0.97,
#         -1: 0.974
#     },
#     {
#         1: 0.982,
#         2: 0.989,
#         3: 0.989,
#         4: 0.97,
#         5: 0.982,
#         6: 0.982,
#         7: 0.989,
#         -1: 0.983
#     }
# )

# %%
_ = gr_ca.show({'raw': gr_ca.pi, 'pr': pi}, vmin=0.1, vmax=1.0, figsize=(25, 5))

# %%
# %%time

boot = bootstrap(
    x=pi_prune,
    n_resamples=int(1e3),
    statistic=lambda a: avg(a, 2, 1),
    skip=['d0'],
    dims=4,
)
se = bn.nanstd(boot, 0, ddof=1)
boot.shape, se.shape
# Out:
# CPU times: user 9min 21s, sys: 2min 21s, total: 11min 43s
# Wall time: 11min 43s
# ((1000, 7, 542), (7, 542))

# %%
reject, pvals = gr_ca.ttest(se, pi, mu=0.05)
counts = collections.Counter(reject.sum(0))
counts, 1 - counts.get(1) / sum(counts.values())
# Out:
# (Counter({1.0: 123, 2.0: 196, 3.0: 154, 4.0: 66, 5.0: 3}), 0.7730627306273062)

# %%
reject, pvals = gr_ca.ttest(se, pi, mu=0.1)
counts = collections.Counter(reject.sum(0))
counts, 1 - counts.get(1) / sum(counts.values())
# Out:
# (Counter({1.0: 212, 2.0: 224, 3.0: 101, 4.0: 5}), 0.6088560885608856)

# %%
reject, pvals = gr_ca.ttest(se, pi, mu=0.15)
counts = collections.Counter(reject.sum(0))
counts, 1 - counts.get(1) / sum(counts.values())
# Out:
# (Counter({1.0: 292, 2.0: 215, 3.0: 35}), 0.46125461254612543)

# %%
reject, pvals = gr_ca.ttest(se, pi, mu=0.2)
counts = collections.Counter(reject.sum(0))
counts, 1 - counts.get(1) / sum(counts.values())
# Out:
# (Counter({1.0: 373, 2.0: 161, 0.0: 1, 3.0: 7}), 0.3118081180811808)

# %%
reject, pvals = gr_ca.ttest(se, pi, mu=1/gr_ca.num_k)
counts = collections.Counter(reject.sum(0))
counts, 1 - counts.get(1) / sum(counts.values())
# Out:
# (Counter({1.0: 278, 2.0: 221, 3.0: 43}), 0.48708487084870844)

# %%
disjoint = reject.sum(0) == 1
mixed = reject.sum(0) > 1

# %%
mixed.sum() / (mixed.sum() + disjoint.sum())
# Out:
# 0.4870848708487085

# %%
community_sizes = reject.sum(1)
community_sizes
# Out:
# array([ 56., 142., 144., 176., 138., 119.,  74.])

# %%
members = reject == 1
np.round((members * mixed).sum(1) / members.sum(1) * 100)
# Out:
# array([100.,  39.,  47.,  78.,  88.,  60.,  86.])

# %%
_ = gr_ca.show({'pr': pi, 'mem': members.astype(float)}, vmin=0.1, vmax=1.0, figsize=(25, 5))

# %%
members = np.zeros(pi.shape)

for i, mu in enumerate([0.5, 0.3, 0.2, 0.1], start=1):
    reject, pvals = gr_ca.ttest(se, pi, mu=mu)
    members[reject == 1] += i

# %%
_ = gr_ca.show({'pr': pi, 'mem': members.astype(float)}, vmin=0.1, vmax=1.0, figsize=(25, 5))

# %%
members /= np.nanmax(members)

# %%
_ = gr_ca.show({'pr': pi, 'mem': members.astype(float)}, vmin=0.1, vmax=1.0, figsize=(25, 5))

# %%
ovp = gr_ca.ovp_score(pi=pi_prune, thres=1/gr_ca.num_k)
list(ovp)
# Out:
# ['se_oc', 'se_node', 'score_oc', 'score_node', 'num_comm']

# %%
ovp['score_oc']
# Out:
# array([63.6492788 , 36.63848407, 29.28838413, 58.75990943, 60.58196807,
#        46.99097561, 54.29056668])

# %%
100 - ovp['score_node'][0]
# Out:
# 31.311132470580077

# %%
ovp['score_node']
# Out:
# array([68.68886753, 28.22872002,  2.74899883,  0.33341362,  0.        ,
#         0.        ,  0.        ])

# %%
ovp = gr_ca.ovp_score(pi=pi_prune, thres=1/gr_ca.num_k)

# %%
np.round((members * mixed).sum(1) / members.sum(1) * 100)
# Out:
# array([85., 32., 42., 71., 81., 52., 79.])

# %%
np.round(ovp['score_oc'])
# Out:
# array([71., 43., 34., 69., 67., 54., 62.])

# %%
np.round(ovp['score_node'])
# Out:
# array([62., 32.,  5.,  1.,  0.,  0.,  0.])
